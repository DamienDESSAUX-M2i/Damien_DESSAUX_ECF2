# %%
import numpy as np
import pandas as pd
from pathlib import Path

OUTPUT_DIR = Path("../output").resolve()
TABLEAUX_SYNTHESE_PATH = OUTPUT_DIR / "tableaux_synthese"
CONSOMMATIONS_ENRICHIES_PARQUET_PATH = OUTPUT_DIR / "consommations_enrichies"
CONSOMMATIONS_ENRICHIES_CSV_PATH = OUTPUT_DIR / "consommations_enrichies.csv"

# %%
df = pd.read_parquet(CONSOMMATIONS_ENRICHIES_PARQUET_PATH.as_posix())
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['date'] = pd.to_datetime(df['date'])
df['date_debut'] = pd.to_datetime(df['date'])
df['date_fin'] = pd.to_datetime(df['date'])
df['type_energie'] = df['type_energie'].astype("str")

df.info()
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7492584 entries, 0 to 7492583
# Data columns (total 37 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   batiment_id                    object
#  1   timestamp                      datetime64[ns]
#  2   consommation                   float64
#  3   unite                          object
#  4   hour                           int32
#  5   year                           int32
#  6   month                          int32
#  7   date                           datetime64[ns]
#  8   nom                            object
#  9   type                           object
#  10  commune                        object
#  11  surface_m2                     int32
#  12  annee_construction             int32
#  13  classe_energetique             object
#  14  nb_occupants_moyen             int32
#  15  intensite_energetique          float64
#  16  type_energie                   object
#  17  temperature_c                  float64
#  18  humidite_pct                   float64
#  19  rayonnement_solaire_wm2        float64
#  20  vitesse_vent_kmh               float64
#  21  precipitation_mm               float64
#  22  day_of_week                    float64
#  23  season                         object
#  24  date_debut                     datetime64[ns]
#  25  date_fin                       datetime64[ns]
#  26  tarif_unitaire                 float64
#  27  consommation_par_occupant      float64
#  28  consommation_par_m2            float64
#  29  consommation_journaliere       float64
#  30  cout_journalier                float64
#  31  cout_mensuel                   float64
#  32  cout_annuel                    float64
#  33  consommation_annuelle          float64
#  34  IPE                            float64
#  35  consommation_moyenne_par_type  float64
#  36  ecart_conso_moyenne_type       float64
# dtypes: datetime64[ns](4), float64(19), int32(6), object(8)
# memory usage: 1.9+ GB
#   batiment_id           timestamp  consommation unite  hour  year  month  \
# 0     BAT0056 2024-01-13 08:00:00          5.23    m3     8  2024      1
# 1     BAT0001 2024-01-13 04:00:00          0.22    m3     4  2024      1
# 2     BAT0056 2024-01-13 17:00:00          3.42    m3    17  2024      1
# 3     BAT0001 2024-01-13 09:00:00          2.30    m3     9  2024      1
# 4     BAT0056 2024-01-13 19:00:00          3.68    m3    19  2024      1
# 5     BAT0001 2024-01-13 10:00:00          3.81    m3    10  2024      1
# 6     BAT0057 2024-01-13 07:00:00          0.82    m3     7  2024      1
# 7     BAT0001 2024-01-13 13:00:00          2.68    m3    13  2024      1
# 8     BAT0057 2024-01-13 11:00:00          1.36    m3    11  2024      1
# 9     BAT0002 2024-01-13 09:00:00          1.49    m3     9  2024      1
#
#         date               nom    type  ... consommation_par_occupant  \
# 0 2024-01-13   Ecole Nantes 56   ecole  ...                  0.038741
# 1 2024-01-13     Ecole Paris 1   ecole  ...                  0.000978
# 2 2024-01-13   Ecole Nantes 56   ecole  ...                  0.025333
# 3 2024-01-13     Ecole Paris 1   ecole  ...                  0.010222
# 4 2024-01-13   Ecole Nantes 56   ecole  ...                  0.027259
# 5 2024-01-13     Ecole Paris 1   ecole  ...                  0.016933
# 6 2024-01-13  Mairie Nantes 57  mairie  ...                  0.023429
# 7 2024-01-13     Ecole Paris 1   ecole  ...                  0.011911
# 8 2024-01-13  Mairie Nantes 57  mairie  ...                  0.038857
# 9 2024-01-13     Ecole Paris 2   ecole  ...                  0.003706
#
#    consommation_par_m2  consommation_journaliere cout_journalier  \
# 0             0.003350                  2.573913        9.652174
# 1             0.000114                  1.989130        7.459239
# 2             0.002191                  2.573913        9.652174
# 3             0.001194                  1.989130        7.459239
# 4             0.002357                  2.573913        9.652174
# 5             0.001978                  1.989130        7.459239
# 6             0.000728                  0.961304        3.604891
# 7             0.001391                  1.989130        7.459239
# 8             0.001208                  0.961304        3.604891
# 9             0.001289                  0.859091        3.221591
#
#    cout_mensuel  cout_annuel consommation_annuelle        IPE  \
# 0    27548.8875  315022.9875              84006.13  53.815586
# 1    21864.1500  252612.6000              67363.36  34.975784
# 2    27548.8875  315022.9875              84006.13  53.815586
# 3    21864.1500  252612.6000              67363.36  34.975784
# 4    27548.8875  315022.9875              84006.13  53.815586
# 5    21864.1500  252612.6000              67363.36  34.975784
# 6     9985.0500  115972.2750              30925.94  27.465311
# 7    21864.1500  252612.6000              67363.36  34.975784
# 8     9985.0500  115972.2750              30925.94  27.465311
# 9     9279.5625  104863.2375              27963.53  24.189905
#
#    consommation_moyenne_par_type  ecart_conso_moyenne_type
# 0                       7.617028                  0.686620
# 1                       7.617028                  0.028883
# 2                       7.617028                  0.448994
# 3                       7.617028                  0.301955
# 4                       7.617028                  0.483128
# 5                       7.617028                  0.500195
# 6                       2.727374                  0.300656
# 7                       7.617028                  0.351843
# 8                       2.727374                  0.498648
# 9                       7.617028                  0.195614
#
# [10 rows x 37 columns]

# %% [markdown]
# #### Etape 3.3 : Detection d'anomalies
# - Identifier les pics de consommation anormaux (>3 ecarts-types)

# %%
std_conso = df.groupby(["batiment_id", "type_energie"]).agg(consommation_std=("consommation", "std"), consommation_mean=("consommation", "mean"))

df_anomalie = df.join(std_conso, ["batiment_id", "type_energie"], "left")

df_pics_conso = df_anomalie.loc[df_anomalie["consommation"] > df_anomalie["consommation_mean"] + 3 * df_anomalie["consommation_std"]]

print(f"  Nombre de pics de consommation : {len(df_pics_conso)}")
# Out:
#   Nombre de pics de consommation : 5258

# %% [markdown]
# - Detecter les periodes de sous-consommation suspectes (batiment ferme non declare)

# %%
df_sous_conso = df_anomalie.loc[df_anomalie["consommation"] < df_anomalie["consommation_mean"] - 1.49 * df_anomalie["consommation_std"]]

print(f"  Nombre de sous consommation (inférieure à la moyenne moins 1.49 écart type) : {len(df_sous_conso)}")
# Out:
#   Nombre de sous consommation (inférieure à la moyenne moins 1.49 écart type) : 37

# %% [markdown]
# - Reperer les batiments dont la consommation ne correspond pas a leur DPE

# %%
def trouver_classe_energetique(ipe: float) -> str:
    if ipe < 70:
        return "A"
    elif ipe < 110:
        return "B"
    elif ipe < 180:
        return "C"
    elif ipe < 250:
        return "D"
    elif ipe < 330:
        return "E"
    elif ipe < 420:
        return "F"
    return "G"

classe_energie = df.loc[df["type_energie"].isin(["gaz", "electricite"])].copy()
classe_energie = (
    classe_energie
    .groupby(["batiment_id", "nom", "type", "commune", "classe_energetique", "type_energie"])
    .agg(IPE=("IPE", "first"))
    .reset_index()
)
classe_energie = (
    classe_energie
    .groupby(["batiment_id", "nom", "type", "commune", "classe_energetique"])
    .agg(IPE=("IPE", "sum"))
    .reset_index()
)
classe_energie["classe_energetique_reelle"] = classe_energie["IPE"].apply(lambda x: trouver_classe_energetique(x))

dpe_errone = classe_energie.loc[classe_energie["classe_energetique_reelle"] != classe_energie["classe_energetique"]]
dpe_errone.head(10)
# Out:
#    batiment_id                  nom         type commune classe_energetique  \
# 0      BAT0001        Ecole Paris 1        ecole   Paris                  E
# 1      BAT0002        Ecole Paris 2        ecole   Paris                  C
# 2      BAT0003        Ecole Paris 3        ecole   Paris                  D
# 3      BAT0004  Mediatheque Paris 4  mediatheque   Paris                  C
# 5      BAT0006       Mairie Paris 6       mairie   Paris                  E
# 6      BAT0007      Gymnase Paris 7      gymnase   Paris                  C
# 8      BAT0009         Ecole Lyon 9        ecole    Lyon                  B
# 11     BAT0012       Mairie Lyon 12       mairie    Lyon                  F
# 12     BAT0013      Gymnase Lyon 13      gymnase    Lyon                  D
# 14     BAT0015       Mairie Lyon 15       mairie    Lyon                  F
#
#             IPE classe_energetique_reelle
# 0   1567.996101                         G
# 1   1085.332647                         G
# 2   1205.882124                         G
# 3   1191.847365                         G
# 5   1180.977562                         G
# 6   1763.649884                         G
# 8    847.573068                         G
# 11  1548.070731                         G
# 12  1953.540345                         G
# 14  1541.633999                         G

# %% [markdown]
# Le calcul de l'IPE étant faux, le DPE réel n'a pas de sens ici.

# %% [markdown]
# - Lister les batiments necessitant un audit energetique

# %%
df_pics_conso = (
    df_pics_conso
    .groupby(["batiment_id", "nom", "type", "commune", "classe_energetique"])
    .agg(consommation_annuelle=("consommation_annuelle", "first"))
    .reset_index()
)

print(f"  Nombre de bâtiment avec pics de consommation anormale : {len(df_pics_conso)}")
print(df_pics_conso.head(5))
print()

df_sous_conso = (
    df_sous_conso
    .groupby(["batiment_id", "nom", "type", "commune", "classe_energetique"])
    .agg(consommation_annuelle=("consommation_annuelle", "first"))
    .reset_index()
)

print(f"  Nombre de bâtiment sous consommation anormale : {len(df_sous_conso)}")
print(df_sous_conso.head(5))
print()

print(f"  Nombre de bâtiment avec DPE erroné : {len(dpe_errone)}")
print(dpe_errone.head(5))
print()
# Out:
#   Nombre de bâtiment avec pics de consommation anormale : 58
#   batiment_id             nom    type commune classe_energetique  \
# 0     BAT0001   Ecole Paris 1   ecole   Paris                  E
# 1     BAT0002   Ecole Paris 2   ecole   Paris                  C
# 2     BAT0003   Ecole Paris 3   ecole   Paris                  D
# 3     BAT0006  Mairie Paris 6  mairie   Paris                  E
# 4     BAT0009    Ecole Lyon 9   ecole    Lyon                  B
#
#    consommation_annuelle
# 0             1209940.44
# 1              498641.66
# 2              818575.26
# 3              552840.06
# 4              797137.96
#
#   Nombre de bâtiment sous consommation anormale : 1
#   batiment_id                 nom     type commune classe_energetique  \
# 0     BAT0146  Piscine Toulon 146  piscine  Toulon                  F
#
#    consommation_annuelle
# 0             1544051.93
#
#   Nombre de bâtiment avec DPE erroné : 106
#   batiment_id                  nom         type commune classe_energetique  \
# 0     BAT0001        Ecole Paris 1        ecole   Paris                  E
# 1     BAT0002        Ecole Paris 2        ecole   Paris                  C
# 2     BAT0003        Ecole Paris 3        ecole   Paris                  D
# 3     BAT0004  Mediatheque Paris 4  mediatheque   Paris                  C
# 5     BAT0006       Mairie Paris 6       mairie   Paris                  E
#
#            IPE classe_energetique_reelle
# 0  1567.996101                         G
# 1  1085.332647                         G
# 2  1205.882124                         G
# 3  1191.847365                         G
# 5  1180.977562                         G

# %%
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
df_pics_conso.to_csv(OUTPUT_DIR / "pics_consommation.csv")
df_sous_conso.to_csv(OUTPUT_DIR / "sous_consommation.csv")
dpe_errone.to_csv(OUTPUT_DIR / "dpe_errone.csv")

# %% [markdown]
# **Livrables** :
# - Notebook `08_detection_anomalies.ipynb`
# - Liste des anomalies `output/anomalies_detectees.csv`
# - Rapport de recommandations d'audit
